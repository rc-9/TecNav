# %% [markdown]
# # PART 1: DATA FABRICATION
#
# **Objective:** As there are no publicly-available datasets that fit the scope of this project, this notebook will execute a series of strategic data fabrication steps to generate the necessary datasets needed down the project pipeline.
#
# ---

# %%
# Data Management
import pandas as pd

# Data Manipulation
import numpy as np
from scipy.stats import truncnorm

# Utils
import math
import datetime
from datetime import timedelta
from faker import Faker
from random import shuffle, choice, randrange

# %%
# Instantiate data fabricator 
faker = Faker()

# %% [markdown]
# ---
# ---
#
# ## 1A: Clinic Information
#
# **Objective:** Generate a dataset consisting of clinic names, locations, and distances.
#
# ---
#
# **Methodology / Approach:**
#
# A total of 5 clinics located around the Denver area will be fabricated to include the following information:
# - `cities` : Name of the clinic branch location (serves as index)
# - `lat` : Latitude of clinic
# - `lon` : Longitude of clinic
# - `to_denver` : Shortest distance to arrive at Denver location from clinic
# - `to_edgewater` : Shortest distance to arrive at Edgewater location from clinic
# - `to_wheatridge` : Shortest distance to arrive at Wheatridge location from clinic
# - `to_rino` : Shortest distance to arrive at RINO location from clinic
# - `to_lakewood` : Shortest distance to arrive at Lakewood location from clinic
# - `nearby_clinics` : The nearest (within ~5 miles) clinics
#
# The urgent care branch locations for each of the 5 clinics was chosen around 5 known Denver areas, with corresponding latitude / longitude / distance values retrieved from Google Maps. This data will be used to also feature engineer the `nearby_clinics` attribute which will be useful for connecting nearby clinical staff members.
#
# *Note: In production, the clinic location & distances data would be retrieved through Google Maps' official API. This will enable us to account for real-time directions / drive-time between locations to periodically update "nearest" clinic info for better accuracy. However, that is is a cost-based service, and therefore the information was manually compiled for the purporses of this project. The shortest distance will be used in lieu of drive-time as the basis for "nearest" distinction.*

# %% [markdown]
# #### Generate a clinic dataset with names, locations, and distances:

# %%
# Construct the clinic dataframe based on Google Maps data
clinics_df = pd.DataFrame({
    'branch_name': ['denver', 'edgewater', 'wheatridge', 'rino', 'lakewood'],
    'lat': [39.73906432357836, 39.753954449845445, 39.76685732722651, 39.767327859566265, 39.70455155721396],
    'lon': [-104.98969659655802, -105.06778796142915, -105.08198265044479, -104.98113186098168, -105.0798829449297],
    'denver': [0, 5, 6.3, 1.9, 7.5],      # shortest dist. (miles) to Denver branch from each clinic
    'edgewater': [5.1, 0, 2, 7.8, 4.3],   # shortest dist. (miles) to Edgewater branch from each clinic
    'wheatridge': [6.3, 2, 0, 7.5, 12],   # shortest dist. (miles) to Wheatridge branch from each clinic
    'rino':[2, 7.7, 7.8, 0, 11],          # shortest dist. (miles) to RINO branch from each clinic
    'lakewood':[8, 4.4, 4.8, 10.7, 0]     # shortest dist. (miles) to Lakewood branch from each clinic
}) 

clinics_df = clinics_df.set_index('branch_name', drop=True)

# %% [markdown]
# #### Feature engineer "nearby" clinic info based on distances:

# %%
distances = clinics_df[['denver', 'edgewater', 'wheatridge', 'rino', 'lakewood']].to_dict()

# %%
# Instantiate empty list to hold lists of nearby clinics for each location
nearby_clinics = []

# Iterate through each branch location
for index, row in clinics_df.iterrows(): 
    nearest = []
    dist_to_clinic = ['denver', 'edgewater', 'wheatridge', 'rino', 'lakewood']
    
    # Collect clinic names that are within threshold distance from location
    for dist in dist_to_clinic:
        if row[dist] > 0: # and round(row[dist]) <= 5:
            city = dist #.split('to_')[1]
            nearest.append((city, row[dist]))
            nearest.sort(key=lambda x: x[1])
    nearby_clinics.append(nearest)
    

# Add nearby clinic info to dataframe
clinics_df['nearby_clinics'] = nearby_clinics

# %%
clinics_df
# Out:
#                    lat         lon  denver  edgewater  wheatridge  rino  \
# branch_name
# denver       39.739064 -104.989697     0.0        5.1         6.3   2.0
# edgewater    39.753954 -105.067788     5.0        0.0         2.0   7.7
# wheatridge   39.766857 -105.081983     6.3        2.0         0.0   7.8
# rino         39.767328 -104.981132     1.9        7.8         7.5   0.0
# lakewood     39.704552 -105.079883     7.5        4.3        12.0  11.0
#
#              lakewood                                     nearby_clinics
# branch_name
# denver            8.0  [(rino, 2.0), (edgewater, 5.1), (wheatridge, 6...
# edgewater         4.4  [(wheatridge, 2.0), (lakewood, 4.4), (denver, ...
# wheatridge        4.8  [(edgewater, 2.0), (lakewood, 4.8), (denver, 6...
# rino             10.7  [(denver, 1.9), (wheatridge, 7.5), (edgewater,...
# lakewood          0.0  [(edgewater, 4.3), (denver, 7.5), (rino, 11.0)...

# %% [markdown]
# ---
# ---
#
# ## 1B: Employee Records
#
# **Objective:** Generate a dataset consisting employee names, IDs, and roles.
#
# ---
#
# **Methodology / Approach:**
#
# A dataset will be constructed for a total of 15 providers and 35 technicians and include the following features:
# - `e_id` : Employee's ID (serves as index)
# - `e_name` : Employee's name
# - `e_role` : Employee's role (provider vs technician)
#
# As there are 5 clinics, and 2 providers are generally assigned to a clinic per day, a total of 15 employees will be distinguished as providers (physicians / physician assistants). The remaining 35 employees in this dataset will be distinguished as 'technicians' which for the purposes of this project are moveable among clinics. For simplicity and relevancy, other employee types are discluded in this dataset as there won't be a part of the analysis or modeling.

# %%
# Specify desired counts
num_docs = 15
num_techs = 35

# %% [markdown]
# ### Employee IDs

# %%
def generate_ids(num_employees):
    """Generates 2-digit staff IDs based on input number of employees."""
    
    eids = list(range(11, num_employees+11))
    return eids

# %% [markdown]
# ### Employee Names

# %%
def generate_names(eids):
    """Generates randomized employee names. Input employee IDs are used for seeding purposes."""

    e_names = []
    for eid in eids:
        Faker.seed(eid)  # for consistency
        e_names.append(faker.unique.name())
    return e_names

# %% [markdown]
# ### Employee Roles

# %%
def generate_roles(num_docs, num_techs):
    """Generates employee roles based on pre-determined tally."""
    
    roles = []
    
    # Generate role title strings based on input tally
    for i in range(num_docs):
        roles.append('Provider')
    for j in range(num_techs):
        roles.append('Technician')
    
    shuffle(roles)
    return roles

# %% [markdown]
# ### Compile employee information and construct dataset:

# %%
# Generate employee IDs based on desired number of each role
eids = generate_ids(num_docs+num_techs)

employees_df = pd.DataFrame({
    'e_id': eids,
    'e_name': generate_names(eids),
    'e_role': generate_roles(num_docs, num_techs)
})
employees_df = employees_df.set_index('e_id', drop=True)

employees_df.sample(5)
# Out:
#                e_name      e_role
# e_id
# 16        John Butler  Technician
# 39          James Lee  Technician
# 41       David Martin  Technician
# 33       Lynn Montoya  Technician
# 20    Melissa Miranda  Technician

# %% [markdown]
# ---
# ---
#
# ## 1C: Patient Records ("Past Year")
#
# **Objective:** Generate a dataset consisting of past patient records including the location & date/time of visit.
#
# ---
#
# **Methodology / Approach:**
#
# Past patient records will include the following information:
# - `pt_id` : Patient's assigned ID number
# - `pt_name` : Patient's name
# - `pt_dob` : Patient's date of birth
# - `pt_age` : Patient's age (engineered from dob)
# - `visit_reason` : Patient's reason for visiting clinic
# - `visit_location` : Clinic visited
# - `visit_date` : Date of visit
# - `checkin_time` : Time the patient checked-in to clinic
# - `checkout_time` : Time the patient checked-out of clinic
# <br>
# Only information relevant to the study will be included in this dataset. Address, insurance, and official diagnosis / code are not going to be generated for this set as it is irrelevant for the purpose of the patient records, which is to inform the scheduler.
#
# According to American Academy of Urgent Care Medicine (AAUCM), the average urgent care sees about 60-80 patients per day. Therefore, in order to generate a dataset of past patient records for each of the 5 chain clinics, this guideline measure will be used to fabricate records for an entire year's worth of data.
#
# To simulate real-world data, each location was strategically chosen from different areas that would see different traffic of incoming patients based on city size and location. To that extent, corresponding proportion of total yearly patients was decided as 0.25 for the more-populated Denver & Lakewood locations, 0.2 for Wheatridge, and 0.15 for the smaller Edgewater and RINO areas. Based on the size computed from the proportion, a list consisting of location names was constructed to be inputted as the locations that patients visited in the patient records.
#
# First, a series of helper functions will be defined for data generation of each corresponding attribute. Additional functions to add "noise" to the data will also be strategically setup. Then, data will be constructed for each clinic and compiled together for end output.

# %% [markdown]
# ### Patient IDs

# %%
def generate_ids(branch, num_pts):
    """Generates 7-digit patient IDs based on input clinic location and patient count."""
    
    # Define starting ID code based on branch location
    start_digit = {
        'denver': 1000001, 
        'edgewater': 2000001, 
        'wheatridge': 3000001, 
        'rino': 4000001, 
        'lakewood': 5000001
    }
    
    # Generate IDs based on start digit and num_pts
    start_id = start_digit[branch]
    end_id = start_id + num_pts
    pids = list(range(start_id, end_id))
    
    return pids

# %% [markdown]
# Since there will be a total of over 100000 patient logs generated, each patient will be given an ID for easier data handling. This ID number was chosen to be 7-digits so that the length is standardized across all patients. As each location's data will be built independently, for easier data handling, the starting digit was distinguished accordingly to prevent data leakage.

# %% [markdown]
# ### Patient Names

# %%
def generate_names(pids): 
    """Generates randomized patient names. Input patient IDs are used for seeding purposes."""
    pt_names = []
    for pid in pids:
        Faker.seed(pid)  # for consistency
        pt_names.append(faker.unique.name())
    return pt_names

# %% [markdown]
# A function was set up to generate randomized names through `Faker` module. A seed (based on unique patient ID) will be used to ensure each run yields consistently the exact same names.

# %% [markdown]
# ### Patient DOBs / Ages

# %%
def generate_dobs(num_pts):
    """Generates date of births based on real-world distributions (with added noise)."""
    
    # Construct dict of age groups with corresponding age range and proportion
    age_probs = {
        'age_group_1': [0, 10, 0.14],
        'age_group_2': [11, 20, 0.15],
        'age_group_3': [21, 30, 0.18],
        'age_group_4': [31, 40, 0.16],
        'age_group_5': [41, 50, 0.13],
        'age_group_6': [51, 60, 0.11],
        'age_group_7': [61, 80, 0.13],
    }
    
    dobs = []
    
    # Iterate through each age group and generate DOBs
    for key, val in age_probs.items():
        
        # Assign appropriate naming for easy-to-follow data handling
        min_age, max_age, p = val[0], val[1], val[2]
        
        # Compute number of patients in this age group
        num_pts_in_group = int(num_pts * p)  # floor multiplication
        
        # Iterate through each patient in the current iteration of age group
        for i in range(num_pts_in_group):
            Faker.seed(i)
            dob = faker.date_of_birth(minimum_age=min_age, maximum_age=max_age)
            dobs.append(dob)
    
    # Account for patient-count discrepancy due to rounding/floor multiplication
    discrepancy = num_pts - len(dobs)
    for i in range(discrepancy):
        # Assign leftover patients to the most popular age group
        dob = faker.date_of_birth(minimum_age=21, maximum_age=30) 
        dobs.append(dob)    
    
    # Randomize order of DOBs (so not in order of age groups)
    shuffle(dobs) 
    
    return dobs

# %% [markdown]
# The function above is setup to take an input number of patients (so that it can be called individually for each branch location).
#
# According to The Journal Of Urgent Care Medicine (JUCM), patient visits can be broken down by the following age proportions:
# - Infant to 10: 13.8%
# - 11 to 20: 14.8%
# - 21 to 30: 18.3%
# - 31 to 40: 15.9%
# - 41 to 50: 12.8%
# - 51 to 60: 11.2%
# - 61+: 13.3
#
# Therefore, the function was designed to closely adhere to this distribution as possible. These proportions were slightly rounded to yield whole numbers and age-limit caps at the max end to account for the extremely rare 80+ patients. Lastly, it was important to set seed for each iteration to yield a consistent set of dates for each run and account for any leftover patients due to floor multiplication of the proportions.

# %%
def convert_dob(dob):
    """Converts input date of birth to age, based on today's date."""

    today = datetime.date.today()
    age = today.year - dob.year - ((today.month, today.day) < (dob.month, dob.day))
    return age

# %% [markdown]
# The helper function above feature engineers each DOB value into age. Age is computed using the current date of script execution.

# %% [markdown]
# ### Reason for Visit (& Code)

# %%
def generate_reasons(num_pts):
    """Generates randomized list of reasons-of-visit based on sensible proportions."""
    
    reason_probs = {
        'cold/flu/fever': 12/80,
        'sore-throat': 5.5/80, 
        'cough': 5.8/80, 
        'chest-pain': 5/80,
        'stomach-pain': 4.5/80, 
        'diarrhea': 0.8/80, 
        'weakness/dizziness': 2.7/80,
        'headache': 2.6/80, 
        'UTI': 4/80, 
        'pink-eye': 0.7/80, 
        'ear-pain': 5.3/80, 
        'rash/allergy': 2.5/80, 
        'cuts/abscess': 1.5/80,
        'ache/pain': 5/80, 
        'injury/accident': 1.5/80, 
        'covid-test': 7.5/80, 
        'vaccination': 5.6/80, 
        'physical': 1/80, 
        'drug-test': 3/80, 
        'blood/lab-work': 3.5/80
    }
    
    reasons = []
    
    # Iterate through each common visit-reasons
    for reason, prob in reason_probs.items():
        
        # Compute number of patients from input total based on reason prob
        num_pts_for_reason = int(num_pts * prob)  # floor multiplication
        
        # Based on pt count for reason, add reasons to master list
        reasons.extend([reason for i in range(num_pts_for_reason)])
    
    # Account for patient-count discrepancy due to rounding/floor multiplication
    discrepancy = num_pts - len(reasons)
    for i in range(discrepancy):
        # Assign leftover patients to the most popular reason
        reasons.append('cold/flu/fever')    
    
    # Randomize order of reasons
    shuffle(reasons) 
    
    return reasons

# %% [markdown]
# The function above generates patient visit-reasons. 20 of the most common visit-reasons were chosen based on CDC data, as well as, personal work experience. Although literature was sought to strategize the tuning of these proportions, only ER data was available which isn't directly applicable for urgent cares. Therefore, for this segment, personal work experience in urgent cares was drawn from to tune the appropriate amount of reason types. This variation in the data is essentially constructed for more insightful EDA and to simulate the streaming as close to real-life as possible. In production, these values would be replaced by the proportions observed in actual data, rather than pure fabrication.

# %%
def generate_severity_code(reason):
    """Outputs a severity-level for input reason of visit."""
    
    # Construct a dict of reasons and corresponding code
    reasons_code = {
        'cold/flu/fever': 4, 
        'sore-throat': 4, 
        'cough': 4,  
        'chest-pain': 5, 
        'stomach-pain': 5,
        'diarrhea': 5, 
        'weakness/dizziness': 5,
        'headache': 5, 
        'UTI': 4, 
        'pink-eye': 4,
        'ear-pain': 4,
        'rash/allergy': 5,
        'cuts/abscess': 5, 
        'ache/pain': 4, 
        'injury/accident': 5, 
        'covid-test': 4,  
        'vaccination': 3,
        'physical': 3, 
        'drug-test': 3, 
        'blood/lab-work': 3
    }
    
    # Output corresponding severity level / code
    code = reasons_code[reason]    
    return code

# %% [markdown]
# The helper function above was setup as a possible added layer of sophistication for patient data. It generates the severity code based on patient-visit reasons that would affect reaction time of technicians and other staff members when faced with multiple waiting patients. The set {3, 4, 5} was chosen based on a 3-tiered system followed at urgent care clinics in St. Louis, MO (based on work-experience). This information will also be useful for exploratory visualizations to inform scheduling and modeling stages down the pipeline.

# %% [markdown]
# ### Patient Visit-Dates

# %%
def generate_dates(ppd):
    """Generates dates data based on input patients-per-day array of past year."""
    
    # Get unique dates from past year
    past_yr_dates = pd.date_range(datetime.date(2021,5,1), periods=365).tolist()
    
    # Generate duplicate dates for each unique date based on patient-per-day records
    dates_all = []
    for i in range(len(past_yr_dates)):
        date = past_yr_dates[i]
        dates_all.extend([date] * ppd[i])
    
    return dates_all

# %% [markdown]
# The function above takes in an input array consisting of the daily patient tally for an entire year for a single clinic. Based on that information, it will fabricate dates records for all patients belonging to that clinic. Note: COVID-related reasons "cold/flu/fever", etc. are not representative of Denver's 2021-2022 waves. Rather, it is meant to reflect moreso the latter stages of a pandemic where tests and cases are not in its peak for the objective of this simulation project.

# %% [markdown]
# ### Patient Check-In Times

# %%
### Define possible specifications for each location's peak hours / "noise"

# Denver-Clinic: 
denver_ctime_specs = {
    'weekday_means1': [8, 8.25, 8.5, 8.75, 9],         # First weekday peak possibilities of Denver location
    'weekday_means2': [11, 11.25, 11.5, 11.75, 12],    # Second weekday peak possibilities of Denver location
    'weekday_means3': [16.5, 17, 17.5, 18, 18.5],      # Third weekday peak possibilities of Denver location
    'weekday_sigmas': [0.6, 0.8, 1.0, 1.2],            # Possible weekday variations (standard-deviations)
    'weekend_means1': [10.5, 11, 11.5, 12],            # First weekend peak possibilities of Denver location
    'weekend_means2': [14, 14.5, 15, 15.5],            # Second weekend peak possibilities of Denver location
    'weekend_means3': [17, 17.25, 17.5, 17.75, 18],    # Third weekend peak possibilities of Denver location
    'weekend_sigmas': [0.6, 1.2, 1.8, 2.4]             # Possible weekend variations (standard-deviations)
}

# Edgewater-Clinic: 
edgewater_ctime_specs = {
    'weekday_means1': [9, 9.25, 9.5, 9.75, 10],        # First weekday peak possibilities of Edgewater location
    'weekday_means2': [13, 13.5, 14, 14.5, 15],        # Second weekday peak possibilities of Edgewater location
    'weekday_means3': [18, 18.5, 19, 19.5, 19.75],     # Third weekday peak possibilities of Edgewater location
    'weekday_sigmas': [0.6, 0.8, 1.0, 1.2],            # Possible weekday variations (standard-deviations)
    'weekend_means1': [8, 8.25, 8.5, 8.75, 9],         # First weekend peak possibilities of Edgewater location
    'weekend_means2': [12, 12.25, 12.5, 12.75, 13],    # Second weekend peak possibilities of Edgewater location
    'weekend_means3': [16, 16.25, 16.5, 16.75, 16],    # Third weekend peak possibilities of Edgewater location
    'weekend_sigmas': [0.6, 1.2, 1.8, 2.4]             # Possible weekend variations (standard-deviations)
}
    
# Wheatridge-Clinic: 
wheatridge_ctime_specs = {
    'weekday_means1': [8, 8.25, 8.5, 8.75, 9],         # First weekday peak possibilities of Wheatridge location
    'weekday_means2': [11, 11.25, 11.5, 11.75, 12],    # Second weekday peak possibilities of Wheatridge location
    'weekday_means3': [16.5, 17, 17.5, 18, 18.5],      # Third weekday peak possibilities of Wheatridge location
    'weekday_sigmas': [0.6, 0.8, 1.0, 1.2],            # Possible weekday variations (standard-deviations)
    'weekend_means1': [10.5, 11, 11.5, 12],            # First weekend peak possibilities of Wheatridge location
    'weekend_means2': [14, 14.5, 15, 15.5],            # Second weekend peak possibilities of Wheatridge location
    'weekend_means3': [17, 17.25, 17.5, 17.75, 18],    # Third weekend peak possibilities of Wheatridge location
    'weekend_sigmas': [0.6, 1.2, 1.8, 2.4]             # Possible weekend variations (standard-deviations)
}

# RINO-Clinic: 
rino_ctime_specs = {
    'weekday_means1': [9, 9.25, 9.5, 9.75, 10],        # First weekday peak possibilities of RINO location
    'weekday_means2': [13, 13.5, 14, 14.5, 15],        # Second weekday peak possibilities of RINO location
    'weekday_means3': [18, 18.5, 19, 19.5, 19.75],     # Third weekday peak possibilities of RINO location
    'weekday_sigmas': [0.6, 0.8, 1.0, 1.2],            # Possible weekday variations (standard-deviations)
    'weekend_means1': [8, 8.25, 8.5, 8.75, 9],         # First weekend peak possibilities of RINO location
    'weekend_means2': [12, 12.25, 12.5, 12.75, 13],    # Second weekend peak possibilities of RINO location
    'weekend_means3': [16, 16.25, 16.5, 16.75, 16],    # Third weekend peak possibilities of RINO location
    'weekend_sigmas': [0.6, 1.2, 1.8, 2.4]             # Possible weekend variations (standard-deviations)
}

# Lakewood-Clinic: 
lakewood_ctime_specs = {
    'weekday_means1': [8.5, 9, 9.5, 10, 10.5],         # First weekday peak possibilities of Lakewood location
    'weekday_means2': [11.5, 12, 12.5, 13],            # Second weekday peak possibilities of Lakewood location
    'weekday_means3': [15.5, 16, 17, 17.5, 19],        # Third weekday peak possibilities of Lakewood location
    'weekday_sigmas': [0.6, 0.8, 1.0, 1.2],            # Possible weekday variations (standard-deviations)
    'weekend_means1': [10.5, 11, 11.5, 12],            # First weekend peak possibilities of Lakewood location
    'weekend_means2': [15, 15.5, 16, 16.5],            # Second weekend peak possibilities of Lakewood location
    'weekend_means3': [19, 19.25, 19.5, 19.75],        # Third weekend peak possibilities of Lakewood location
    'weekend_sigmas': [0.6, 1.2, 1.8, 2.4]             # Possible weekend variations (standard-deviations)
}

# %% [markdown]
# "Peak-Hours" specifications for the bi-modal week-day model and normal week-end models are specified above for each location. To best capture the diversity that exists in real-world urgent care clinic's daily influx charts (according to Google Maps' "Popular Times" feature), different peaks and standard deviations are strategically setup above. These will be used and further tuned to generate the patient check-in times information.

# %%
### WEEKDAY CHECK-IN TIME GENERATOR
def generate_weekday_ctimes(N, means, sigmas):
    """Generates N check-in times from tri-modal model based on input means & sigmas."""
    
    # Specify the lower and upper limit based on clinic operating times (8am-8pm / 8:00-20:00)
    low, upp = 8, 20
    
    # Split N into three groups
    leftover = N % 3
    N_vals = [int(N/3), int(N/3), int(N/3)+leftover]
    
    # Create a set of times distributed around the three input means
    X = []
    for i in range(3):
        vals = truncnorm((low - means[i]) / sigmas[i], (upp - means[i]) / sigmas[i], loc=means[i], scale=sigmas[i])
        vals = vals.rvs(N_vals[i])
        X.append(vals)
    
    # Concatenate the three weekday "peaks"
    X = np.concatenate([X[0],X[1],X[2]])
    
    return X

### WEEKEND CHECK-IN TIME GENERATOR
def generate_weekend_ctimes(N, means, sigmas):
    """Generates N check-in times from tri-modal model based on input means & sigmas."""
    
    # Specify the lower and upper limit based on clinic operating times (8am-8pm / 8:00-20:00)
    low, upp = 8, 20
    
    # Split N into three groups
    leftover = N % 3
    N_vals = [int(N/3), int(N/3), int(N/3)+leftover]
    
    # Create a set of times distributed around two input means
    X = []
    for i in range(3):
        vals = truncnorm((low - means[i]) / sigmas[i], (upp - means[i]) / sigmas[i], loc=means[i], scale=sigmas[i])
        vals = vals.rvs(N_vals[i])
        X.append(vals)
    
    # Concatenate the two weekday "peaks"
    X = np.concatenate([X[0],X[1],X[2]])
    
    return X


### TIME GENERATOR
def generate_ctimes(ppd, branch_specs):
    """Calls on appropriate functions with corresponding branch specs to generate check-in times."""
    
    check_in_times = []
    
    # Define unique dates of last year
    dates = pd.date_range(datetime.date(2021,5,1), periods=365).tolist()

    for i in range(len(dates)):
        
        # Examine whether date is weekend or weekday
        day = dates[i].weekday()
        
        # Gather specs and generate check-in times for weekend
        if day == 5 or day == 6:
            means = [choice(branch_specs['weekend_means1']), choice(branch_specs['weekend_means2']), choice(branch_specs['weekend_means3'])]
            sigmas = [choice(branch_specs['weekend_sigmas']), choice(branch_specs['weekend_sigmas']), choice(branch_specs['weekend_sigmas'])]
            ctimes = generate_weekday_ctimes(ppd[i], means, sigmas)
            check_in_times.extend(ctimes)   
        
        # Gather specs and generate check-in times for weekdays
        else:
            means = [choice(branch_specs['weekday_means1']), choice(branch_specs['weekday_means2']), choice(branch_specs['weekday_means3'])]
            sigmas = [choice(branch_specs['weekday_sigmas']), choice(branch_specs['weekday_sigmas']), choice(branch_specs['weekday_sigmas'])]
            ctimes = generate_weekday_ctimes(ppd[i], means, sigmas)
            check_in_times.extend(ctimes)      
        
    return check_in_times
    

### HELPER FUNCTION
def convert_time(x):
    """Converts time from decimal format to appropriate datetime object."""
    
    # Grab each portion of input time
    hour = int(abs(x))
    leftover_decimal = x - hour
    minutes = int(leftover_decimal * 60)
    seconds = int(leftover_decimal * 60 * 60 % 60)
    
    # Convert to datetime object
    time = datetime.time(hour, minutes, seconds).strftime('%X')
    
    return time

# %% [markdown]
# The function above was created to generate weekday check-in times based on a tri-modal (3 "peaks") distribution, one for each part of the day. Another function is setup to generate weekend check-in times based on a single distribution. Lastly, a helper function was created to convert each time value from float to appropriate datetime object.

# %% [markdown]
# ### Patient Check-Out Times

# %%
def generate_checkout_times(data):
    """Generates a checkout time (with added 'noise') based on check-in time and reason of visit."""
    
    # Unpack input date
    check_in_time, reason = data[0], data[1]
    
    # Construct a dict of reasons and expected time of stay
    reasons_time = {
        'cold/flu/fever': 45, 
        'sore-throat': 30, 
        'cough': 30,  
        'chest-pain': 60, 
        'stomach-pain': 60,
        'diarrhea': 60, 
        'weakness/dizziness': 60,
        'headache': 45, 
        'UTI': 45, 
        'pink-eye': 30,
        'ear-pain': 30,
        'rash/allergy': 45,
        'cuts/abscess': 45, 
        'ache/pain': 30, 
        'injury/accident': 60, 
        'covid-test': 20,  
        'vaccination': 20,
        'physical': 20, 
        'drug-test': 20, 
        'blood/lab-work': 30
    }
    
    # Possible variations in appointment time (in minutes)
    variations = [i for i in range(-5, 5, 1)]
    
    # Compute check-out time based on check-in time with added "noise"/variation
    check_in_time = datetime.datetime.strptime(check_in_time, '%H:%M:%S')
    checkout_time = check_in_time + timedelta(minutes=reasons_time[reason] + choice(variations))
    
    return checkout_time

# %% [markdown]
# The function above is setup to be used as part of dataframe's apply/map functionality to take an input of both the patient's reason of visit & check-in-time and output a computed check-out time. As data is unavailable for the specific tuning of the length of visits per reason, personal experience working at urgent-care facilities was once again relied upon to determine these values. To add extra "noise" to these times, each checkout time is outputted with a variation in minutes.

# %% [markdown]
# ### "Past" Patient Influx (per Clinic & per Day)

# %%
### Generate lists of patients-per-day at each location

ppd_denver = np.random.normal(-7, 7, 365)
ppd_denver = ppd_denver + 80
ppd_denver = ppd_denver.astype(int)

ppd_edgewater = np.random.normal(-5, 5, 365)
ppd_edgewater = ppd_edgewater + 55
ppd_edgewater = ppd_edgewater.astype(int)

ppd_wheatridge = np.random.normal(-6, 6, 365)
ppd_wheatridge = ppd_wheatridge + 65
ppd_wheatridge = ppd_wheatridge.astype(int)

ppd_rino = np.random.normal(-4, 4, 365)
ppd_rino = ppd_rino + 60
ppd_rino = ppd_rino.astype(int)

ppd_lakewood = np.random.normal(-6, 6, 365)
ppd_lakewood = ppd_lakewood + 70
ppd_lakewood = ppd_lakewood.astype(int)

# DEBUG / EXAMINATION
for ppd in [ppd_denver, ppd_edgewater, ppd_wheatridge, ppd_rino, ppd_lakewood]:
    # print(len(ppd))
    # print(pd.DataFrame(ppd).describe())
    # print(ppd)
    continue

# %% [markdown]
# The code-block above constructs lists for each clinic branch, consisting of the patient counts for each day of the past year. For the purposes of generating "noise" in this data fabrication step, numbers were pulled from the normal distribution based on a different input mean per location. This input mean was decided based on the populations of each area. This will allow for added noise to replicate real-world data as much as possible and pave the way for the remaining features of the patient dataset handled below.

# %% [markdown]
# ### Compile patient information for each clinic, feature-engineer desired attributes, and construct finalized dataset:

# %%
def rolling_stats(branch_df):
    """Generates rolling count of patients in clinic for each record for input branch's records."""
    
    rolling_ct = []
    rolling_severities = []
    
    # Iterate through each possible data
    for date in branch_df['visit_date'].unique():
        
        # Grab the corresponding check-in & check-out times and severity codes for the date
        checkins = branch_df[branch_df.visit_date==date].checkin_time.values
        df = branch_df.copy()
        df['checkout_time'] = df['checkout_time'].apply(lambda x: x.time())
        checkouts = df[df.visit_date==date].checkout_time.values
        severity_levels = branch_df[branch_df.visit_date==date].visit_code.values
        
        # Iterate through each check-in time
        for i in range(len(checkins)):
            
            # Current iteration of check-in time
            current_checkin = checkins[i]
            
            # Instantiate patient count at 1
            counter = 1
            current_severities = [0]
            
            # Iterate through all past check-out times (before current check-in time)
            for j in range(i):
                
                # If previous patient's check-out time is after current patient's check-in time, increment counter
                if checkouts[j] > current_checkin:
                    counter += 1
                    current_severities.append(severity_levels[j])
            
            # Average out visit codes for patients currently in clinic 
            if len(current_severities) == 1:
                mean_severity = 0
            else:
                mean_severity = np.mean(current_severities[1:])
            
            rolling_ct.append(counter)
            rolling_severities.append(round(mean_severity, 1))
            
            
    return rolling_ct, rolling_severities

# %% [markdown]
# The helper function above iterates through patient records and tracks how many patients are in a clinic at the time a new patient walks in. This will be useful for EDA and modeling purposes to better inform the scheduling process.

# %%
def generate_dataset(branch, ppd, specs):
    """Executes necessary functions to generate patient records for a input branch location."""
    
    # Grab total number of pts visiting input branch location in past year
    num_pts = ppd.sum() 

    # Execute functions to generate data for each attribute
    ids = generate_ids(branch, num_pts)
    names = generate_names(ids)
    dobs = generate_dobs(num_pts)
    ages = [convert_dob(dob) for dob in dobs]
    locations = [branch for i in range(num_pts)]
    reasons = generate_reasons(num_pts)
    codes = [generate_severity_code(reason) for reason in reasons]
    dates = generate_dates(ppd)
    checkin_times = generate_ctimes(ppd, specs)
    checkin_times = [convert_time(time) for time in checkin_times]

    # Construct dataframe from generated data
    pts_df = pd.DataFrame({
        'pt_id': ids,
        'pt_name': names,
        'pt_dob': dobs,
        'pt_age': ages,
        'visit_location': locations,
        'visit_reason': reasons,
        'visit_code': codes,
        'visit_date': dates,
        'checkin_time': checkin_times
    })

    # Create check-out times
    pts_df['checkout_time'] = pts_df[['checkin_time', 'visit_reason']].apply(generate_checkout_times, axis=1)

    # Ensure check-in times are in datetime format
    pts_df['checkin_time'] = pts_df['checkin_time'].apply(lambda x: datetime.datetime.strptime(x, '%H:%M:%S').time())

    # Sort records based on visit_date and checkin_time
    pts_df = pts_df.sort_values(['visit_date', 'checkin_time', 'checkout_time'])
    
    # Feature-engineer a rolling count and a rolling severity level of patients in clinic
    pts_df['rolling_ct'], pts_df['rolling_code'] = rolling_stats(pts_df)
    
    # Adjust check-out time based on clinic's current rolling severity-code
    pts_df['checkout_time'] = pts_df[['checkout_time', 'rolling_code']].apply(lambda x: x[0] + datetime.timedelta(minutes=x[1] * 10), axis=1)
    pts_df['checkout_time'] = pts_df['checkout_time'].apply(lambda x: x.time())
    
    # Feature-engineer day information based on dates
    pts_df['visit_day'] = pts_df['visit_date'].apply(lambda x: x.weekday()) \
            .map({0: 'Monday', 1: 'Tuesday', 2: 'Wednesday', 3: 'Thursday', 4: 'Friday', 5: 'Saturday', 6: 'Sunday'})
    
    # Rearrange column order as desired
    pts_df = pts_df[[
        'pt_id', 'pt_name', 'pt_dob', 'pt_age',                                                     # Patient Info
        'visit_location', 'visit_reason', 'visit_code',                                             # Visit Info (Location & Reason)
        'visit_date', 'visit_day', 'checkin_time', 'checkout_time', 'rolling_ct', 'rolling_code'    # Visit Info (Day/Date/Time)
    ]]
    
    return pts_df

# %%
### DENVER
denver_df = generate_dataset('denver', ppd_denver, denver_ctime_specs)

### EDGEWATER
edgewater_df = generate_dataset('edgewater', ppd_edgewater, edgewater_ctime_specs)

### WHEATRIDGE
wheatridge_df = generate_dataset('wheatridge', ppd_wheatridge, wheatridge_ctime_specs)

### RINO
rino_df = generate_dataset('rino', ppd_rino, rino_ctime_specs)

### LAKEWOOD
lakewood_df = generate_dataset('lakewood', ppd_lakewood, lakewood_ctime_specs)

### TOTAL
patients_df = pd.concat([denver_df, edgewater_df, wheatridge_df, rino_df, lakewood_df], axis=0)
patients_df = patients_df.set_index('pt_id', drop=True)
# patients_df

# %% [markdown]
# ---
# ---
#
# ## 1D: New Patient Records (for "real-time" streaming)
#
# **Objective:** Generate a dataset consisting of patient records that will be streamed for real-time model.
#
# ---
#
# **Methodology / Approach:**
#
# This dataset will consist of the same attributes existing in the past petient records, as the info taken at registration when a patient enters the clinic.

# %% [markdown]
# ---
# ---
#
# ## 1E: Output
#
# **Objective:** Save constructed datasets into *CSV* files for use in the next stages of the project pipeline.
#
# ---

# %%
clinics_df.to_csv('./uc_clinics.csv')

clinics_df
# Out:
#                    lat         lon  denver  edgewater  wheatridge  rino  \
# branch_name
# denver       39.739064 -104.989697     0.0        5.1         6.3   2.0
# edgewater    39.753954 -105.067788     5.0        0.0         2.0   7.7
# wheatridge   39.766857 -105.081983     6.3        2.0         0.0   7.8
# rino         39.767328 -104.981132     1.9        7.8         7.5   0.0
# lakewood     39.704552 -105.079883     7.5        4.3        12.0  11.0
#
#              lakewood                                     nearby_clinics
# branch_name
# denver            8.0  [(rino, 2.0), (edgewater, 5.1), (wheatridge, 6...
# edgewater         4.4  [(wheatridge, 2.0), (lakewood, 4.4), (denver, ...
# wheatridge        4.8  [(edgewater, 2.0), (lakewood, 4.8), (denver, 6...
# rino             10.7  [(denver, 1.9), (wheatridge, 7.5), (edgewater,...
# lakewood          0.0  [(edgewater, 4.3), (denver, 7.5), (rino, 11.0)...

# %%
employees_df.to_csv('./uc_employees.csv')

employees_df.sample(5)
# Out:
#                e_name      e_role
# e_id
# 13     Michael Sutton  Technician
# 49    Jason Rodriguez    Provider
# 51    Jonathan Martin  Technician
# 58      Christine May    Provider
# 52        Amy Swanson    Provider

# %%
patients_df.to_csv('./uc_past_patients.csv')
patients_df
# Out:
#                        pt_name      pt_dob  pt_age visit_location  \
# pt_id
# 1000024           Dawn Jackson  1947-09-17      74         denver
# 1000010           Paul Hammond  1995-08-28      26         denver
# 1000004  Christopher Clark Jr.  1948-04-03      74         denver
# 1000013        Kimberly Davies  1973-05-15      48         denver
# 1000002          Joshua Oliver  1985-05-16      36         denver
# ...                        ...         ...     ...            ...
# 5023297           Brianna Horn  2016-07-13       5       lakewood
# 5023285      Stephen Gallagher  1958-02-10      64       lakewood
# 5023291     Allen Gonzalez Jr.  2010-02-15      12       lakewood
# 5023281           Paul Webster  1997-09-20      24       lakewood
# 5023288        Natasha Stewart  1995-01-21      27       lakewood
#
#            visit_reason  visit_code visit_date visit_day checkin_time  \
# pt_id
# 1000024        pink-eye           4 2021-05-01  Saturday     08:00:16
# 1000010       ache/pain           4 2021-05-01  Saturday     08:23:22
# 1000004  cold/flu/fever           4 2021-05-01  Saturday     08:32:23
# 1000013  blood/lab-work           3 2021-05-01  Saturday     08:54:10
# 1000002             UTI           4 2021-05-01  Saturday     09:00:25
# ...                 ...         ...        ...       ...          ...
# 5023297       ache/pain           4 2022-04-30  Saturday     19:42:39
# 5023285  cold/flu/fever           4 2022-04-30  Saturday     19:47:40
# 5023291       drug-test           3 2022-04-30  Saturday     19:48:08
# 5023281           cough           4 2022-04-30  Saturday     19:49:52
# 5023288        physical           3 2022-04-30  Saturday     19:58:14
#
#         checkout_time  rolling_ct  rolling_code
# pt_id
# 1000024      08:34:16           1           0.0
# 1000010      09:29:22           2           4.0
# 1000004      09:56:23           3           4.0
# 1000013      10:03:10           2           4.0
# 1000002      10:20:25           3           3.5
# ...               ...         ...           ...
# 5023297      20:53:39           3           4.5
# 5023285      21:15:40           4           4.3
# 5023291      20:54:08           5           4.2
# 5023281      20:54:52           6           4.0
# 5023288      20:55:14           7           4.0
#
# [109466 rows x 12 columns]

# %%
daily_df = patients_df.groupby(['visit_location', 'visit_date', 'visit_day']).max().reset_index(drop=False)[['visit_location', 'visit_date', 'rolling_ct']]
daily_df['num_techs'] = daily_df.rolling_ct.copy().apply(lambda x: int(x/3)+1)
daily_df[daily_df.visit_location == 'lakewood']
# Out:
#      visit_location visit_date  rolling_ct  num_techs
# 730        lakewood 2021-05-01          11          4
# 731        lakewood 2021-05-02          10          4
# 732        lakewood 2021-05-03           9          4
# 733        lakewood 2021-05-04          13          5
# 734        lakewood 2021-05-05           7          3
# ...             ...        ...         ...        ...
# 1090       lakewood 2022-04-26          16          6
# 1091       lakewood 2022-04-27          12          5
# 1092       lakewood 2022-04-28          11          4
# 1093       lakewood 2022-04-29          11          4
# 1094       lakewood 2022-04-30          10          4
#
# [365 rows x 4 columns]

# %%
zipper = zip(daily_df.visit_date, daily_df.visit_location, daily_df.num_techs)
d = {}
for i in zipper:
    d[(i[0], i[1])] = i[2]

patients_df['num_techs'] = patients_df[['visit_date', 'visit_location']].copy() \
    .apply(lambda x: (x[0], x[1]), axis=1) \
    .map(d)
patients_df.tail(70)
# Out:
#                     pt_name      pt_dob  pt_age visit_location  \
# pt_id
# 5023238        Howard Mason  1952-02-29      70       lakewood
# 5023231        Joshua Bruce  2013-06-10       8       lakewood
# 5023229          Evan Ortiz  2006-03-03      16       lakewood
# 5023233       Raymond Moses  1996-03-26      26       lakewood
# 5023222  Mrs. Brenda Warren  2015-05-31       6       lakewood
# ...                     ...         ...     ...            ...
# 5023297        Brianna Horn  2016-07-13       5       lakewood
# 5023285   Stephen Gallagher  1958-02-10      64       lakewood
# 5023291  Allen Gonzalez Jr.  2010-02-15      12       lakewood
# 5023281        Paul Webster  1997-09-20      24       lakewood
# 5023288     Natasha Stewart  1995-01-21      27       lakewood
#
#                visit_reason  visit_code visit_date visit_day checkin_time  \
# pt_id
# 5023238  weakness/dizziness           5 2022-04-29    Friday     16:22:26
# 5023231  weakness/dizziness           5 2022-04-29    Friday     16:24:59
# 5023229            headache           5 2022-04-29    Friday     16:42:42
# 5023233          covid-test           4 2022-04-29    Friday     16:43:59
# 5023222                 UTI           4 2022-04-29    Friday     16:47:25
# ...                     ...         ...        ...       ...          ...
# 5023297           ache/pain           4 2022-04-30  Saturday     19:42:39
# 5023285      cold/flu/fever           4 2022-04-30  Saturday     19:47:40
# 5023291           drug-test           3 2022-04-30  Saturday     19:48:08
# 5023281               cough           4 2022-04-30  Saturday     19:49:52
# 5023288            physical           3 2022-04-30  Saturday     19:58:14
#
#         checkout_time  rolling_ct  rolling_code  num_techs
# pt_id
# 5023238      18:03:26           7           4.5          4
# 5023231      18:06:59           8           4.6          4
# 5023229      18:12:42           7           4.7          4
# 5023233      17:46:59           8           4.7          4
# 5023222      18:14:25           8           4.7          4
# ...               ...         ...           ...        ...
# 5023297      20:53:39           3           4.5          4
# 5023285      21:15:40           4           4.3          4
# 5023291      20:54:08           5           4.2          4
# 5023281      20:54:52           6           4.0          4
# 5023288      20:55:14           7           4.0          4
#
# [70 rows x 13 columns]

# %%
datetime = []
for i in zip(patients_df.visit_date, patients_df.checkin_time):
    datetime.append(str(i[0].date()) + ' ' + str(i[1]))

patients_df['datetime'] = datetime
patients_df.head()
# Out:
#                        pt_name      pt_dob  pt_age visit_location  \
# pt_id
# 1000024           Dawn Jackson  1947-09-17      74         denver
# 1000010           Paul Hammond  1995-08-28      26         denver
# 1000004  Christopher Clark Jr.  1948-04-03      74         denver
# 1000013        Kimberly Davies  1973-05-15      48         denver
# 1000002          Joshua Oliver  1985-05-16      36         denver
#
#            visit_reason  visit_code visit_date visit_day checkin_time  \
# pt_id
# 1000024        pink-eye           4 2021-05-01  Saturday     08:00:16
# 1000010       ache/pain           4 2021-05-01  Saturday     08:23:22
# 1000004  cold/flu/fever           4 2021-05-01  Saturday     08:32:23
# 1000013  blood/lab-work           3 2021-05-01  Saturday     08:54:10
# 1000002             UTI           4 2021-05-01  Saturday     09:00:25
#
#         checkout_time  rolling_ct  rolling_code  num_techs  \
# pt_id
# 1000024      08:34:16           1           0.0          6
# 1000010      09:29:22           2           4.0          6
# 1000004      09:56:23           3           4.0          6
# 1000013      10:03:10           2           4.0          6
# 1000002      10:20:25           3           3.5          6
#
#                     datetime
# pt_id
# 1000024  2021-05-01 08:00:16
# 1000010  2021-05-01 08:23:22
# 1000004  2021-05-01 08:32:23
# 1000013  2021-05-01 08:54:10
# 1000002  2021-05-01 09:00:25

# %%
patients_df['needed_techs'] = patients_df['rolling_ct'].apply(lambda x: math.ceil(x/3))
patients_df.head(50)
# Out:
#                        pt_name      pt_dob  pt_age visit_location  \
# pt_id
# 1000024           Dawn Jackson  1947-09-17      74         denver
# 1000010           Paul Hammond  1995-08-28      26         denver
# 1000004  Christopher Clark Jr.  1948-04-03      74         denver
# 1000013        Kimberly Davies  1973-05-15      48         denver
# 1000002          Joshua Oliver  1985-05-16      36         denver
# 1000016        Anthony Johnson  2003-07-26      18         denver
# 1000014             Janet Rowe  1955-06-20      66         denver
# 1000018            Jerome Hall  2007-05-10      14         denver
# 1000015         Tracey Winters  1988-10-27      33         denver
# 1000009         Laura Anderson  1993-01-31      29         denver
# 1000012         Jennifer Smith  1976-02-08      46         denver
# 1000022           Lori Walters  1989-07-28      32         denver
# 1000020         Rachael Chavez  1942-05-30      79         denver
# 1000001             Kevin Howe  1985-03-31      37         denver
# 1000017           Laura Wright  1961-09-04      60         denver
# 1000003         Erica Thompson  1987-08-30      34         denver
# 1000023     Christopher Wright  1989-08-05      32         denver
# 1000005          Blake Spencer  1958-03-09      64         denver
# 1000007           Debra Huerta  1994-01-13      28         denver
# 1000008          Karen Donovan  1975-06-29      46         denver
# 1000006          Darius Barnes  1996-06-23      25         denver
# 1000011        Meghan Richards  2016-07-16       5         denver
# 1000021          Karen Lambert  1976-07-29      45         denver
# 1000034         Michelle Clark  2008-03-01      14         denver
# 1000043           David Huerta  1997-01-05      25         denver
# 1000033            Tamara Cook  2004-04-16      18         denver
# 1000027       Bradley Martinez  1971-09-24      50         denver
# 1000029            James Nunez  1999-09-29      22         denver
# 1000048             Joe Walker  1975-09-02      46         denver
# 1000046           Makayla Bell  1962-08-05      59         denver
# 1000038          Felicia Riley  1987-04-01      35         denver
# 1000025        Tracy Hernandez  1991-10-27      30         denver
# 1000039         Jennifer Ayala  1988-11-28      33         denver
# 1000044          Kurt Thompson  2004-12-14      17         denver
# 1000037            James Wolfe  2003-09-07      18         denver
# 1000047           Tiffany Beck  1960-05-03      62         denver
# 1000026          Kara Mitchell  2000-03-16      22         denver
# 1000036          Bruce Jackson  2017-01-18       5         denver
# 1000042         Benjamin Smith  2010-10-22      11         denver
# 1000041           Katie Decker  1994-09-18      27         denver
# 1000032            Adam Fisher  1974-06-22      47         denver
# 1000035       Rebecca Richards  1993-06-29      28         denver
# 1000031      Tina Clements DVM  1977-10-27      44         denver
# 1000019         Jeffrey Landry  2014-07-14       7         denver
# 1000040       Sarah Richardson  1965-01-06      57         denver
# 1000030              Daisy Lee  2004-05-05      18         denver
# 1000045     Melissa Russell MD  2007-10-08      14         denver
# 1000028              Troy King  2018-03-24       4         denver
# 1000067        Garrett Hawkins  1997-10-31      24         denver
# 1000071        Robert Mcdaniel  1973-10-28      48         denver
#
#                visit_reason  visit_code visit_date visit_day checkin_time  \
# pt_id
# 1000024            pink-eye           4 2021-05-01  Saturday     08:00:16
# 1000010           ache/pain           4 2021-05-01  Saturday     08:23:22
# 1000004      cold/flu/fever           4 2021-05-01  Saturday     08:32:23
# 1000013      blood/lab-work           3 2021-05-01  Saturday     08:54:10
# 1000002                 UTI           4 2021-05-01  Saturday     09:00:25
# 1000016            ear-pain           4 2021-05-01  Saturday     09:29:53
# 1000014         sore-throat           4 2021-05-01  Saturday     09:36:06
# 1000018  weakness/dizziness           5 2021-05-01  Saturday     10:24:51
# 1000015      cold/flu/fever           4 2021-05-01  Saturday     10:24:57
# 1000009          covid-test           4 2021-05-01  Saturday     10:30:49
# 1000012      cold/flu/fever           4 2021-05-01  Saturday     10:32:40
# 1000022        stomach-pain           5 2021-05-01  Saturday     10:40:32
# 1000020               cough           4 2021-05-01  Saturday     10:51:11
# 1000001         sore-throat           4 2021-05-01  Saturday     10:58:16
# 1000017               cough           4 2021-05-01  Saturday     11:01:02
# 1000003         sore-throat           4 2021-05-01  Saturday     11:14:21
# 1000023      cold/flu/fever           4 2021-05-01  Saturday     11:18:43
# 1000005          covid-test           4 2021-05-01  Saturday     11:24:34
# 1000007            diarrhea           5 2021-05-01  Saturday     11:35:34
# 1000008           ache/pain           4 2021-05-01  Saturday     11:59:01
# 1000006          chest-pain           5 2021-05-01  Saturday     12:08:03
# 1000011      cold/flu/fever           4 2021-05-01  Saturday     12:49:50
# 1000021          covid-test           4 2021-05-01  Saturday     13:01:29
# 1000034      cold/flu/fever           4 2021-05-01  Saturday     13:31:21
# 1000043            diarrhea           5 2021-05-01  Saturday     13:47:17
# 1000033  weakness/dizziness           5 2021-05-01  Saturday     14:01:00
# 1000027          chest-pain           5 2021-05-01  Saturday     14:01:20
# 1000029         sore-throat           4 2021-05-01  Saturday     14:04:51
# 1000048      cold/flu/fever           4 2021-05-01  Saturday     14:10:07
# 1000046                 UTI           4 2021-05-01  Saturday     14:17:58
# 1000038        rash/allergy           5 2021-05-01  Saturday     14:22:14
# 1000025          covid-test           4 2021-05-01  Saturday     14:22:25
# 1000039         vaccination           3 2021-05-01  Saturday     14:22:59
# 1000044            ear-pain           4 2021-05-01  Saturday     14:27:29
# 1000037            ear-pain           4 2021-05-01  Saturday     14:29:50
# 1000047               cough           4 2021-05-01  Saturday     14:30:46
# 1000026            ear-pain           4 2021-05-01  Saturday     14:32:51
# 1000036        stomach-pain           5 2021-05-01  Saturday     14:36:58
# 1000042               cough           4 2021-05-01  Saturday     14:38:52
# 1000041      blood/lab-work           3 2021-05-01  Saturday     14:42:08
# 1000032      blood/lab-work           3 2021-05-01  Saturday     14:44:23
# 1000035                 UTI           4 2021-05-01  Saturday     14:45:10
# 1000031      cold/flu/fever           4 2021-05-01  Saturday     14:50:38
# 1000019      blood/lab-work           3 2021-05-01  Saturday     15:08:37
# 1000040      cold/flu/fever           4 2021-05-01  Saturday     15:09:02
# 1000030      cold/flu/fever           4 2021-05-01  Saturday     15:14:28
# 1000045           ache/pain           4 2021-05-01  Saturday     15:17:38
# 1000028            ear-pain           4 2021-05-01  Saturday     15:53:51
# 1000067          chest-pain           5 2021-05-01  Saturday     16:16:44
# 1000071        rash/allergy           5 2021-05-01  Saturday     16:36:50
#
#         checkout_time  rolling_ct  rolling_code  num_techs  \
# pt_id
# 1000024      08:34:16           1           0.0          6
# 1000010      09:29:22           2           4.0          6
# 1000004      09:56:23           3           4.0          6
# 1000013      10:03:10           2           4.0          6
# 1000002      10:20:25           3           3.5          6
# 1000016      10:34:53           2           4.0          6
# 1000014      10:50:06           3           4.0          6
# 1000018      11:27:51           1           0.0          6
# 1000015      11:54:57           2           5.0          6
# 1000009      11:31:49           3           4.5          6
# 1000012      12:01:40           4           4.3          6
# 1000022      12:23:32           5           4.2          6
# 1000020      12:08:11           5           4.5          6
# 1000001      12:16:16           6           4.4          6
# 1000017      12:18:02           7           4.3          6
# 1000003      12:22:21           7           4.3          6
# 1000023      12:50:43           7           4.3          6
# 1000005      12:30:34           7           4.3          6
# 1000007      13:17:34           5           4.2          6
# 1000008      13:15:01           3           4.5          6
# 1000006      13:55:03           3           4.5          6
# 1000011      14:26:50           2           5.0          6
# 1000021      14:01:29           3           4.5          6
# 1000034      14:51:21           2           4.0          6
# 1000043      15:29:17           2           4.0          6
# 1000033      15:44:00           3           4.5          6
# 1000027      15:52:20           4           4.7          6
# 1000029      15:23:51           5           4.8          6
# 1000048      15:38:07           6           4.6          6
# 1000046      15:45:58           6           4.6          6
# 1000038      15:56:14           7           4.5          6
# 1000025      15:27:25           8           4.6          6
# 1000039      15:28:59           9           4.5          6
# 1000044      15:38:29          10           4.3          6
# 1000037      15:41:50          11           4.3          6
# 1000047      15:42:46          12           4.3          6
# 1000026      15:46:51          13           4.2          6
# 1000036      16:16:58          13           4.2          6
# 1000042      15:50:52          14           4.3          6
# 1000041      15:57:08          14           4.3          6
# 1000032      15:59:23          14           4.3          6
# 1000035      16:13:10          15           4.2          6
# 1000031      16:18:38          15           4.1          6
# 1000019      16:20:37           7           4.0          6
# 1000040      16:29:02           8           3.9          6
# 1000030      16:33:28           7           3.8          6
# 1000045      16:30:38           7           4.0          6
# 1000028      17:02:51           2           4.0          6
# 1000067      18:00:44           2           4.0          6
# 1000071      18:07:50           2           5.0          6
#
#                     datetime  needed_techs
# pt_id
# 1000024  2021-05-01 08:00:16             1
# 1000010  2021-05-01 08:23:22             1
# 1000004  2021-05-01 08:32:23             1
# 1000013  2021-05-01 08:54:10             1
# 1000002  2021-05-01 09:00:25             1
# 1000016  2021-05-01 09:29:53             1
# 1000014  2021-05-01 09:36:06             1
# 1000018  2021-05-01 10:24:51             1
# 1000015  2021-05-01 10:24:57             1
# 1000009  2021-05-01 10:30:49             1
# 1000012  2021-05-01 10:32:40             2
# 1000022  2021-05-01 10:40:32             2
# 1000020  2021-05-01 10:51:11             2
# 1000001  2021-05-01 10:58:16             2
# 1000017  2021-05-01 11:01:02             3
# 1000003  2021-05-01 11:14:21             3
# 1000023  2021-05-01 11:18:43             3
# 1000005  2021-05-01 11:24:34             3
# 1000007  2021-05-01 11:35:34             2
# 1000008  2021-05-01 11:59:01             1
# 1000006  2021-05-01 12:08:03             1
# 1000011  2021-05-01 12:49:50             1
# 1000021  2021-05-01 13:01:29             1
# 1000034  2021-05-01 13:31:21             1
# 1000043  2021-05-01 13:47:17             1
# 1000033  2021-05-01 14:01:00             1
# 1000027  2021-05-01 14:01:20             2
# 1000029  2021-05-01 14:04:51             2
# 1000048  2021-05-01 14:10:07             2
# 1000046  2021-05-01 14:17:58             2
# 1000038  2021-05-01 14:22:14             3
# 1000025  2021-05-01 14:22:25             3
# 1000039  2021-05-01 14:22:59             3
# 1000044  2021-05-01 14:27:29             4
# 1000037  2021-05-01 14:29:50             4
# 1000047  2021-05-01 14:30:46             4
# 1000026  2021-05-01 14:32:51             5
# 1000036  2021-05-01 14:36:58             5
# 1000042  2021-05-01 14:38:52             5
# 1000041  2021-05-01 14:42:08             5
# 1000032  2021-05-01 14:44:23             5
# 1000035  2021-05-01 14:45:10             5
# 1000031  2021-05-01 14:50:38             5
# 1000019  2021-05-01 15:08:37             3
# 1000040  2021-05-01 15:09:02             3
# 1000030  2021-05-01 15:14:28             3
# 1000045  2021-05-01 15:17:38             3
# 1000028  2021-05-01 15:53:51             1
# 1000067  2021-05-01 16:16:44             1
# 1000071  2021-05-01 16:36:50             1

# %%
patients_df.to_csv('./uc_past_patients.csv')

# %% [markdown]
# ## Tech-Navigation

# %%
test = patients_df.sort_values('datetime') #[50:200]

# %%
test['num_techs'] = test.num_techs.apply(lambda x: x-1)
# test = test[test.visit_date == '2021-05-04']

# %%
import pprint
pp = pprint.PrettyPrinter(indent=0)

d = {'denver': {'checkin_time': None, 'num_techs': 0,'needed_techs': 0, 'flag': 0, 'available_techs': 0, 'num_movements': 0},
     'edgewater': {'checkin_time': None, 'num_techs': 0,'needed_techs': 0, 'flag': 0, 'available_techs': 0, 'num_movements': 0},
     'wheatridge': {'checkin_time': None, 'num_techs': 0,'needed_techs': 0, 'flag': 0, 'available_techs': 0, 'num_movements': 0}, 
     'rino': {'checkin_time': None, 'num_techs': 0,'needed_techs': 0, 'flag': 0, 'available_techs': 0, 'num_movements': 0},
     'lakewood': {'checkin_time': None, 'num_techs': 0,'needed_techs': 0, 'flag': 0, 'available_techs': 0, 'num_movements': 0}}


for row in test.iterrows():
    row = row[1]
    location = row['visit_location']
    checkin_time = row['checkin_time']
    num_techs = row['num_techs']
    needed_techs = row['needed_techs']
    d[location]['checkin_time'] = checkin_time
    d[location]['num_techs'] = num_techs + d[location]['num_movements']
    d[location]['needed_techs'] = needed_techs + d[location]['num_movements']
    available_techs = d[location]['num_techs'] - d[location]['needed_techs']
    d[location]['available_techs'] = available_techs

    # pp.pprint(d[location])
    # print()
    if d[location]['flag'] == 1:
      # print(location)
      # print('flag was 1')
      # pp.pprint(d[location])
      # print()
        if d[location]['num_techs'] < d[location]['needed_techs']:
            print(f"{checkin_time}: {location} needs {needed_techs - num_techs} techs!")
            # avail = [(i, d[i]['available_techs']) for i in d.keys() if d[i]['available_techs'] > 0]
            
            available = []
            for clinic in clinics_df.loc[location, 'nearby_clinics']:
                avail_techs = d[clinic[0]]['available_techs']
                if avail_techs > 0:
                    available.append(clinic)
            print("Check to see what's available: ", available)
            if len(available) > 0:
                pull_from = available[0][0]
                print('Pull tech from:' , pull_from)

                print(f'Original amount of techs at {location}: {num_techs}')
                print(f'Original amount of techs at {pull_from}: {d[pull_from]["num_techs"]}')

                # print('Before move, original location: ', d[location])
                # print('Before move, pull from: ', d[pull_from])

                # subtract 1 from pull_from 
                d[pull_from]['num_movements'] = -1
                # add 1 to location
                d[location]['num_movements'] = 1

                # print('After move, original location: ', d[location])
                # print('After move, pulled from: ', d[pull_from])
                print(f'New amount of techs at {location}: {num_techs + d[location]["num_movements"]}')
                print(f'New amount of techs at {pull_from}: {d[pull_from]["num_techs"] + d[pull_from]["num_movements"]}')

                print()
            else:
                print('No movement since all clinics are busy.')

    else:
        if d[location]['num_techs'] == d[location]['needed_techs']:
            d[location]['flag'] = 1
            # print(location)
            # print('flag = 1')
            # pp.pprint(d[location])
            # print()
# what if denver has 2 and rino only has 1. gotta look to the next location
# Out:
# 08:37:36: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9)]
# Pull tech from: denver
# Original amount of techs at rino: 4
# Original amount of techs at denver: 5
# New amount of techs at rino: 5
# New amount of techs at denver: 4
#
# 08:44:49: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9)]
# Pull tech from: denver
# Original amount of techs at rino: 4
# Original amount of techs at denver: 5
# New amount of techs at rino: 5
# New amount of techs at denver: 4
#
# 11:17:27: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 2
#
# 11:24:58: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 2
#
# 11:34:44: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 2
#
# 09:15:16: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 1
#
# 09:31:28: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 1
#
# 12:10:16: denver needs 1 techs!
# Check to see what's available:  [('lakewood', 8.0)]
# Pull tech from: lakewood
# Original amount of techs at denver: 3
# Original amount of techs at lakewood: 4
# New amount of techs at denver: 4
# New amount of techs at lakewood: 3
#
# 12:15:38: denver needs 1 techs!
# Check to see what's available:  [('lakewood', 8.0)]
# Pull tech from: lakewood
# Original amount of techs at denver: 3
# Original amount of techs at lakewood: 2
# New amount of techs at denver: 4
# New amount of techs at lakewood: 1
#
# 12:21:12: denver needs 1 techs!
# Check to see what's available:  [('lakewood', 8.0)]
# Pull tech from: lakewood
# Original amount of techs at denver: 3
# Original amount of techs at lakewood: 2
# New amount of techs at denver: 4
# New amount of techs at lakewood: 1
#
# 12:22:43: denver needs 1 techs!
# Check to see what's available:  [('lakewood', 8.0)]
# Pull tech from: lakewood
# Original amount of techs at denver: 3
# Original amount of techs at lakewood: 2
# New amount of techs at denver: 4
# New amount of techs at lakewood: 1
#
# 12:24:15: denver needs 1 techs!
# Check to see what's available:  [('lakewood', 8.0)]
# Pull tech from: lakewood
# Original amount of techs at denver: 3
# Original amount of techs at lakewood: 2
# New amount of techs at denver: 4
# New amount of techs at lakewood: 1
#
# 12:39:31: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: edgewater
# Original amount of techs at denver: 3
# Original amount of techs at edgewater: 3
# New amount of techs at denver: 4
# New amount of techs at edgewater: 2
#
# 12:41:01: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: edgewater
# Original amount of techs at denver: 3
# Original amount of techs at edgewater: 1
# New amount of techs at denver: 4
# New amount of techs at edgewater: 0
#
# 12:44:28: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 2
# Original amount of techs at edgewater: 1
# New amount of techs at wheatridge: 3
# New amount of techs at edgewater: 0
#
# 13:20:24: edgewater needs 1 techs!
# Check to see what's available:  [('lakewood', 4.4), ('rino', 7.7)]
# Pull tech from: lakewood
# Original amount of techs at edgewater: 2
# Original amount of techs at lakewood: 2
# New amount of techs at edgewater: 3
# New amount of techs at lakewood: 1
#
# 13:24:53: edgewater needs 1 techs!
# Check to see what's available:  [('lakewood', 4.4), ('rino', 7.7)]
# Pull tech from: lakewood
# Original amount of techs at edgewater: 2
# Original amount of techs at lakewood: 2
# New amount of techs at edgewater: 3
# New amount of techs at lakewood: 1
#
# 14:34:41: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 4
# New amount of techs at denver: 4
# New amount of techs at rino: 3
#
# 17:26:26: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 2
# New amount of techs at denver: 4
# New amount of techs at rino: 1
#
# 18:09:45: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('denver', 6.3), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 2
# Original amount of techs at edgewater: 3
# New amount of techs at wheatridge: 3
# New amount of techs at edgewater: 2
#
# 19:57:20: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 2
#
# 09:11:42: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 4
# Original amount of techs at rino: 2
# New amount of techs at denver: 5
# New amount of techs at rino: 1
#
# 09:25:39: edgewater needs 1 techs!
# Check to see what's available:  [('lakewood', 4.4), ('rino', 7.7)]
# Pull tech from: lakewood
# Original amount of techs at edgewater: 3
# Original amount of techs at lakewood: 4
# New amount of techs at edgewater: 4
# New amount of techs at lakewood: 3
#
# 09:39:40: edgewater needs 1 techs!
# Check to see what's available:  []
# No movement since all clinics are busy.
# 09:41:53: edgewater needs 1 techs!
# Check to see what's available:  []
# No movement since all clinics are busy.
# 13:31:45: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 3
# Original amount of techs at denver: 5
# New amount of techs at rino: 4
# New amount of techs at denver: 4
#
# 13:35:39: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 3
# Original amount of techs at denver: 5
# New amount of techs at rino: 4
# New amount of techs at denver: 4
#
# 17:16:32: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('wheatridge', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at denver: 4
# Original amount of techs at edgewater: 4
# New amount of techs at denver: 5
# New amount of techs at edgewater: 3
#
# 17:17:50: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('wheatridge', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at denver: 4
# Original amount of techs at edgewater: 4
# New amount of techs at denver: 5
# New amount of techs at edgewater: 3
#
# 17:21:45: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('wheatridge', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at denver: 4
# Original amount of techs at edgewater: 4
# New amount of techs at denver: 5
# New amount of techs at edgewater: 3
#
# 17:23:55: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('wheatridge', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at denver: 4
# Original amount of techs at edgewater: 4
# New amount of techs at denver: 5
# New amount of techs at edgewater: 3
#
# 17:29:43: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('wheatridge', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at denver: 4
# Original amount of techs at edgewater: 4
# New amount of techs at denver: 5
# New amount of techs at edgewater: 3
#
# 18:06:54: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('denver', 6.3), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 18:08:38: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('denver', 6.3), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 09:03:43: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('denver', 6.3), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 4
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 5
# New amount of techs at edgewater: 1
#
# 10:13:20: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 3
# Original amount of techs at denver: 5
# New amount of techs at rino: 4
# New amount of techs at denver: 4
#
# 10:14:38: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 3
# Original amount of techs at denver: 5
# New amount of techs at rino: 4
# New amount of techs at denver: 4
#
# 12:29:45: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 4
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 5
# New amount of techs at edgewater: 1
#
# 12:38:39: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 4
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 5
# New amount of techs at edgewater: 1
#
# 19:39:26: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 3
# Original amount of techs at wheatridge: 5
# New amount of techs at edgewater: 4
# New amount of techs at wheatridge: 4
#
# 08:48:00: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('denver', 6.3), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 4
# Original amount of techs at edgewater: 4
# New amount of techs at wheatridge: 5
# New amount of techs at edgewater: 3
#
# 08:56:02: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('denver', 6.3), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 4
# Original amount of techs at edgewater: 4
# New amount of techs at wheatridge: 5
# New amount of techs at edgewater: 3
#
# 09:21:18: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('wheatridge', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at denver: 3
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 4
# New amount of techs at edgewater: 1
#
# 09:32:15: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('wheatridge', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at denver: 3
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 4
# New amount of techs at edgewater: 1
#
# 09:32:36: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('wheatridge', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at denver: 3
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 4
# New amount of techs at edgewater: 1
#
# 09:35:04: rino needs 1 techs!
# Check to see what's available:  [('wheatridge', 7.5), ('edgewater', 7.8)]
# Pull tech from: wheatridge
# Original amount of techs at rino: 3
# Original amount of techs at wheatridge: 5
# New amount of techs at rino: 4
# New amount of techs at wheatridge: 4
#
# 09:40:15: rino needs 1 techs!
# Check to see what's available:  [('wheatridge', 7.5), ('edgewater', 7.8)]
# Pull tech from: wheatridge
# Original amount of techs at rino: 3
# Original amount of techs at wheatridge: 5
# New amount of techs at rino: 4
# New amount of techs at wheatridge: 4
#
# 09:48:15: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('wheatridge', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at denver: 3
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 4
# New amount of techs at edgewater: 1
#
# 11:15:12: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 2
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 3
# New amount of techs at edgewater: 1
#
# 12:33:23: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('wheatridge', 6.3)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 4
# New amount of techs at denver: 4
# New amount of techs at rino: 3
#
# 12:34:05: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('wheatridge', 6.3)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 4
# New amount of techs at denver: 4
# New amount of techs at rino: 3
#
# 13:57:04: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 3
# Original amount of techs at wheatridge: 3
# New amount of techs at edgewater: 4
# New amount of techs at wheatridge: 2
#
# 17:53:22: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 2
# New amount of techs at denver: 4
# New amount of techs at rino: 1
#
# 17:58:14: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('wheatridge', 6.3), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 2
# New amount of techs at denver: 4
# New amount of techs at rino: 1
#
# 17:59:53: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 2
# New amount of techs at denver: 4
# New amount of techs at rino: 1
#
# 18:51:51: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 2
# Original amount of techs at edgewater: 4
# New amount of techs at lakewood: 3
# New amount of techs at edgewater: 3
#
# 19:31:44: edgewater needs 1 techs!
# Check to see what's available:  [('denver', 5.0)]
# Pull tech from: denver
# Original amount of techs at edgewater: 3
# Original amount of techs at denver: 4
# New amount of techs at edgewater: 4
# New amount of techs at denver: 3
#
# 08:43:57: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('denver', 6.3), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 4
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 3
#
# 08:45:45: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('denver', 6.3), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 4
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 3
#
# 08:47:34: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('denver', 6.3), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 08:52:54: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 08:53:39: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 10:09:27: wheatridge needs 1 techs!
# Check to see what's available:  [('lakewood', 4.8)]
# Pull tech from: lakewood
# Original amount of techs at wheatridge: 3
# Original amount of techs at lakewood: 5
# New amount of techs at wheatridge: 4
# New amount of techs at lakewood: 4
#
# 18:00:37: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('wheatridge', 6.3), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 2
# New amount of techs at denver: 4
# New amount of techs at rino: 1
#
# 18:28:17: rino needs 1 techs!
# Check to see what's available:  [('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: wheatridge
# Original amount of techs at rino: 3
# Original amount of techs at wheatridge: 4
# New amount of techs at rino: 4
# New amount of techs at wheatridge: 3
#
# 18:30:17: rino needs 1 techs!
# Check to see what's available:  [('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: wheatridge
# Original amount of techs at rino: 3
# Original amount of techs at wheatridge: 4
# New amount of techs at rino: 4
# New amount of techs at wheatridge: 3
#
# 08:54:04: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('wheatridge', 6.3), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 4
# Original amount of techs at rino: 3
# New amount of techs at denver: 5
# New amount of techs at rino: 2
#
# 09:01:17: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('wheatridge', 6.3), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 4
# Original amount of techs at rino: 3
# New amount of techs at denver: 5
# New amount of techs at rino: 2
#
# 09:04:38: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('wheatridge', 6.3), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 4
# Original amount of techs at rino: 3
# New amount of techs at denver: 5
# New amount of techs at rino: 2
#
# 10:34:54: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 5
# New amount of techs at rino: 3
# New amount of techs at denver: 4
#
# 10:37:42: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 5
# New amount of techs at rino: 3
# New amount of techs at denver: 4
#
# 10:37:56: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 1
#
# 13:58:11: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 3
# New amount of techs at rino: 3
# New amount of techs at denver: 2
#
# 14:09:49: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 3
# New amount of techs at rino: 3
# New amount of techs at denver: 2
#
# 14:13:09: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 3
# New amount of techs at rino: 3
# New amount of techs at denver: 2
#
# 14:13:21: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 3
# New amount of techs at rino: 3
# New amount of techs at denver: 2
#
# 14:21:58: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 3
# New amount of techs at rino: 3
# New amount of techs at denver: 2
#
# 17:51:37: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 4
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 5
# New amount of techs at edgewater: 2
#
# 18:03:16: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 4
# Original amount of techs at edgewater: 1
# New amount of techs at lakewood: 5
# New amount of techs at edgewater: 0
#
# 18:04:22: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 4
# Original amount of techs at edgewater: 1
# New amount of techs at lakewood: 5
# New amount of techs at edgewater: 0
#
# 19:10:47: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 1
#
# 19:21:33: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 1
#
# 13:14:59: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 3
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 4
# New amount of techs at wheatridge: 1
#
# 16:17:43: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 4
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 3
#
# 16:22:56: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 4
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 3
#
# 16:25:40: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 4
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 3
#
# 16:39:38: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 2
# Original amount of techs at edgewater: 4
# New amount of techs at lakewood: 3
# New amount of techs at edgewater: 3
#
# 16:47:02: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 4
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 3
#
# 16:47:50: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 4
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 3
#
# 16:54:12: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 16:58:38: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 16:59:30: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 17:12:15: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 17:14:04: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 17:24:05: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: edgewater
# Original amount of techs at denver: 3
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 4
# New amount of techs at edgewater: 1
#
# 17:38:01: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: edgewater
# Original amount of techs at denver: 3
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 4
# New amount of techs at edgewater: 1
#
# 17:38:58: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: edgewater
# Original amount of techs at denver: 3
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 4
# New amount of techs at edgewater: 1
#
# 17:51:37: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: edgewater
# Original amount of techs at denver: 3
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 4
# New amount of techs at edgewater: 1
#
# 18:14:48: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 2
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 3
# New amount of techs at edgewater: 1
#
# 18:21:56: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 2
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 3
# New amount of techs at edgewater: 1
#
# 09:44:04: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 4
# New amount of techs at rino: 3
# New amount of techs at denver: 3
#
# 09:46:46: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 4
# New amount of techs at rino: 3
# New amount of techs at denver: 3
#
# 10:10:57: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 2
# New amount of techs at rino: 3
# New amount of techs at denver: 1
#
# 10:14:33: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 2
# New amount of techs at rino: 3
# New amount of techs at denver: 1
#
# 10:24:36: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 4
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 3
#
# 10:26:05: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 2
# New amount of techs at rino: 3
# New amount of techs at denver: 1
#
# 11:46:28: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('wheatridge', 6.3), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 3
# New amount of techs at denver: 4
# New amount of techs at rino: 2
#
# 11:46:43: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 1
#
# 11:47:17: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('wheatridge', 6.3), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 3
# New amount of techs at denver: 4
# New amount of techs at rino: 2
#
# 11:50:08: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 1
#
# 11:58:01: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('wheatridge', 6.3), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 1
# New amount of techs at denver: 4
# New amount of techs at rino: 0
#
# 12:12:33: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 1
#
# 13:37:04: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 1
#
# 19:13:11: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 4
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 5
# New amount of techs at edgewater: 2
#
# 19:14:49: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 4
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 5
# New amount of techs at edgewater: 2
#
# 19:15:41: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 4
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 5
# New amount of techs at edgewater: 2
#
# 08:33:20: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('denver', 6.3), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 5
# Original amount of techs at edgewater: 3
# New amount of techs at wheatridge: 6
# New amount of techs at edgewater: 2
#
# 08:37:03: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('denver', 6.3), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 5
# Original amount of techs at edgewater: 3
# New amount of techs at wheatridge: 6
# New amount of techs at edgewater: 2
#
# 08:44:50: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 4
# Original amount of techs at rino: 2
# New amount of techs at denver: 5
# New amount of techs at rino: 1
#
# 09:31:01: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 2
#
# 09:36:00: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 2
#
# 09:52:27: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 2
#
# 17:21:47: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 2
#
# 17:24:37: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 2
#
# 19:16:29: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 4
# Original amount of techs at wheatridge: 6
# New amount of techs at edgewater: 5
# New amount of techs at wheatridge: 5
#
# 19:41:06: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 3
# Original amount of techs at denver: 5
# New amount of techs at rino: 4
# New amount of techs at denver: 4
#
# 09:04:41: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 4
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 3
#
# 09:10:04: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 4
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 3
#
# 09:19:26: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 4
# Original amount of techs at rino: 4
# New amount of techs at denver: 5
# New amount of techs at rino: 3
#
# 09:23:19: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 4
# Original amount of techs at rino: 4
# New amount of techs at denver: 5
# New amount of techs at rino: 3
#
# 09:26:27: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 4
# Original amount of techs at rino: 2
# New amount of techs at denver: 5
# New amount of techs at rino: 1
#
# 10:28:14: lakewood needs 1 techs!
# Check to see what's available:  [('denver', 7.5)]
# Pull tech from: denver
# Original amount of techs at lakewood: 2
# Original amount of techs at denver: 5
# New amount of techs at lakewood: 3
# New amount of techs at denver: 4
#
# 10:38:18: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 2
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 3
# New amount of techs at edgewater: 1
#
# 10:52:47: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 2
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 3
# New amount of techs at edgewater: 1
#
# 10:59:49: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 2
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 3
# New amount of techs at edgewater: 1
#
# 11:32:40: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 2
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 3
# New amount of techs at edgewater: 1
#
# 11:37:44: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 2
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 3
# New amount of techs at edgewater: 1
#
# 09:48:30: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 4
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 3
#
# 10:04:23: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 3
# New amount of techs at rino: 3
# New amount of techs at denver: 2
#
# 13:37:15: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 3
# New amount of techs at rino: 3
# New amount of techs at denver: 2
#
# 14:18:22: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 3
# New amount of techs at rino: 3
# New amount of techs at denver: 2
#
# 15:38:32: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 1
#
# 15:43:41: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 1
#
# 15:51:32: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 1
#
# 17:03:55: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 1
#
# 19:21:42: rino needs 1 techs!
# Check to see what's available:  [('wheatridge', 7.5), ('edgewater', 7.8)]
# Pull tech from: wheatridge
# Original amount of techs at rino: 2
# Original amount of techs at wheatridge: 2
# New amount of techs at rino: 3
# New amount of techs at wheatridge: 1
#
# 09:07:05: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 3
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 2
#
# 09:22:30: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 3
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 2
#
# 09:24:33: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 3
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 2
#
# 09:26:01: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 3
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 2
#
# 10:02:34: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 3
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 2
#
# 12:53:50: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 3
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 2
#
# 18:23:26: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 3
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 2
#
# 18:26:18: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 3
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 2
#
# 18:41:49: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 3
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 2
#
# 18:43:29: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0), ('rino', 7.7)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 2
# Original amount of techs at wheatridge: 3
# New amount of techs at edgewater: 3
# New amount of techs at wheatridge: 2
#
# 16:52:24: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 4
# Original amount of techs at rino: 4
# New amount of techs at denver: 5
# New amount of techs at rino: 3
#
# 17:02:53: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 4
# Original amount of techs at rino: 4
# New amount of techs at denver: 5
# New amount of techs at rino: 3
#
# 17:17:38: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1)]
# Pull tech from: rino
# Original amount of techs at denver: 4
# Original amount of techs at rino: 2
# New amount of techs at denver: 5
# New amount of techs at rino: 1
#
# 11:57:09: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('wheatridge', 6.3), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 4
# New amount of techs at denver: 4
# New amount of techs at rino: 3
#
# 12:01:04: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('wheatridge', 6.3), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 4
# New amount of techs at denver: 4
# New amount of techs at rino: 3
#
# 12:08:52: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 5
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 6
# New amount of techs at edgewater: 2
#
# 12:11:26: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 5
# Original amount of techs at edgewater: 3
# New amount of techs at lakewood: 6
# New amount of techs at edgewater: 2
#
# 12:13:37: denver needs 1 techs!
# ...
# Check to see what's available:  [('denver', 1.9), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 6
# New amount of techs at rino: 3
# New amount of techs at denver: 5
#
# 09:35:40: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 4
# New amount of techs at rino: 3
# New amount of techs at denver: 3
#
# 15:42:11: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 4
# New amount of techs at rino: 3
# New amount of techs at denver: 3
#
# 19:38:12: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 4
# New amount of techs at rino: 3
# New amount of techs at denver: 3
#
# 08:52:02: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 4
# New amount of techs at denver: 4
# New amount of techs at rino: 3
#
# 08:54:01: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 2
# New amount of techs at denver: 4
# New amount of techs at rino: 1
#
# 09:00:42: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('wheatridge', 6.3), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 2
# New amount of techs at denver: 4
# New amount of techs at rino: 1
#
# 09:03:49: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('wheatridge', 6.3), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 2
# New amount of techs at denver: 4
# New amount of techs at rino: 1
#
# 09:38:12: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: edgewater
# Original amount of techs at denver: 3
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 4
# New amount of techs at edgewater: 1
#
# 09:38:14: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: edgewater
# Original amount of techs at denver: 3
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 4
# New amount of techs at edgewater: 1
#
# 10:27:33: lakewood needs 1 techs!
# Check to see what's available:  [('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: denver
# Original amount of techs at lakewood: 3
# Original amount of techs at denver: 4
# New amount of techs at lakewood: 4
# New amount of techs at denver: 3
#
# 10:28:53: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 1
#
# 10:38:49: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 1
#
# 10:43:32: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 1
#
# 10:44:22: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 1
#
# 15:32:39: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 1
#
# 15:34:02: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 1
#
# 17:30:09: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('denver', 6.3), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 4
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 5
# New amount of techs at edgewater: 1
#
# 17:45:44: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('lakewood', 4.8), ('rino', 7.8)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 4
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 5
# New amount of techs at edgewater: 1
#
# 18:01:42: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 2
# New amount of techs at denver: 4
# New amount of techs at rino: 1
#
# 18:03:52: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 2
# New amount of techs at denver: 4
# New amount of techs at rino: 1
#
# 18:08:00: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 3
# Original amount of techs at rino: 2
# New amount of techs at denver: 4
# New amount of techs at rino: 1
#
# 19:50:14: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 3
# Original amount of techs at denver: 4
# New amount of techs at rino: 4
# New amount of techs at denver: 3
#
# 09:11:52: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1)]
# Pull tech from: edgewater
# Original amount of techs at denver: 4
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 5
# New amount of techs at edgewater: 1
#
# 09:14:03: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1)]
# Pull tech from: edgewater
# Original amount of techs at denver: 4
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 5
# New amount of techs at edgewater: 1
#
# 09:14:42: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 09:15:13: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1)]
# Pull tech from: edgewater
# Original amount of techs at denver: 4
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 5
# New amount of techs at edgewater: 1
#
# 09:18:48: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1)]
# Pull tech from: edgewater
# Original amount of techs at denver: 4
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 5
# New amount of techs at edgewater: 1
#
# 09:23:02: denver needs 1 techs!
# Check to see what's available:  [('rino', 2.0), ('edgewater', 5.1), ('lakewood', 8.0)]
# Pull tech from: rino
# Original amount of techs at denver: 4
# Original amount of techs at rino: 4
# New amount of techs at denver: 5
# New amount of techs at rino: 3
#
# 10:02:55: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 1
#
# 10:05:11: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 1
#
# 10:14:03: lakewood needs 1 techs!
# Check to see what's available:  [('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: denver
# Original amount of techs at lakewood: 3
# Original amount of techs at denver: 5
# New amount of techs at lakewood: 4
# New amount of techs at denver: 4
#
# 10:16:34: lakewood needs 1 techs!
# Check to see what's available:  [('denver', 7.5), ('rino', 11.0), ('wheatridge', 12.0)]
# Pull tech from: denver
# Original amount of techs at lakewood: 3
# Original amount of techs at denver: 3
# New amount of techs at lakewood: 4
# New amount of techs at denver: 2
#
# 10:20:05: lakewood needs 1 techs!
# Check to see what's available:  [('denver', 7.5), ('rino', 11.0)]
# Pull tech from: denver
# Original amount of techs at lakewood: 3
# Original amount of techs at denver: 3
# New amount of techs at lakewood: 4
# New amount of techs at denver: 2
#
# 11:51:48: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('rino', 11.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 1
#
# 17:07:44: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('denver', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 19:28:49: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 3
# Original amount of techs at denver: 3
# New amount of techs at rino: 4
# New amount of techs at denver: 2
#
# 19:32:16: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 3
# Original amount of techs at denver: 3
# New amount of techs at rino: 4
# New amount of techs at denver: 2
#
# 19:42:50: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 3
# Original amount of techs at wheatridge: 4
# New amount of techs at edgewater: 4
# New amount of techs at wheatridge: 3
#
# 19:53:33: edgewater needs 1 techs!
# Check to see what's available:  [('wheatridge', 2.0), ('lakewood', 4.4), ('denver', 5.0)]
# Pull tech from: wheatridge
# Original amount of techs at edgewater: 3
# Original amount of techs at wheatridge: 4
# New amount of techs at edgewater: 4
# New amount of techs at wheatridge: 3
#
# 09:24:04: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 3
# New amount of techs at rino: 3
# New amount of techs at denver: 2
#
# 09:32:25: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 3
# New amount of techs at rino: 3
# New amount of techs at denver: 2
#
# 09:44:33: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 3
# New amount of techs at rino: 3
# New amount of techs at denver: 2
#
# 10:00:53: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('edgewater', 7.8), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 3
# New amount of techs at rino: 3
# New amount of techs at denver: 2
#
# 11:29:29: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('wheatridge', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at denver: 4
# Original amount of techs at edgewater: 4
# New amount of techs at denver: 5
# New amount of techs at edgewater: 3
#
# 11:31:49: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1), ('wheatridge', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at denver: 4
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 5
# New amount of techs at edgewater: 1
#
# 11:36:59: denver needs 1 techs!
# Check to see what's available:  [('edgewater', 5.1)]
# Pull tech from: edgewater
# Original amount of techs at denver: 4
# Original amount of techs at edgewater: 2
# New amount of techs at denver: 5
# New amount of techs at edgewater: 1
#
# 12:25:17: edgewater needs 1 techs!
# Check to see what's available:  [('denver', 5.0)]
# Pull tech from: denver
# Original amount of techs at edgewater: 3
# Original amount of techs at denver: 5
# New amount of techs at edgewater: 4
# New amount of techs at denver: 4
#
# 14:56:03: rino needs 1 techs!
# Check to see what's available:  [('denver', 1.9), ('wheatridge', 7.5), ('lakewood', 10.7)]
# Pull tech from: denver
# Original amount of techs at rino: 2
# Original amount of techs at denver: 3
# New amount of techs at rino: 3
# New amount of techs at denver: 2
#
# 15:49:20: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 4
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 3
#
# 15:53:02: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 4
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 3
#
# 15:54:29: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('denver', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 4
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 3
#
# 16:15:52: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('denver', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 16:16:59: wheatridge needs 1 techs!
# Check to see what's available:  [('edgewater', 2.0), ('denver', 6.3)]
# Pull tech from: edgewater
# Original amount of techs at wheatridge: 3
# Original amount of techs at edgewater: 2
# New amount of techs at wheatridge: 4
# New amount of techs at edgewater: 1
#
# 19:18:18: lakewood needs 1 techs!
# Check to see what's available:  [('edgewater', 4.3), ('denver', 7.5), ('wheatridge', 12.0)]
# Pull tech from: edgewater
# Original amount of techs at lakewood: 3
# Original amount of techs at edgewater: 2
# New amount of techs at lakewood: 4
# New amount of techs at edgewater: 1
